# %% [markdown]
# ## Scatter Plot

# %%
# source https://www.youtube.com/watch?v=zZZ_RCwp49g&list=PL-osiE80TeTvipOqomVEeZ1HRrcEvtZB_&index=7
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

# plt.scatter (x, y, s=100, c='green', marker='x')
plt.scatter (x, y, s=100, c='green', edgecolor='black', linewidth=1, alpha=0.75)
# colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]



# data = pd.read_csv('2019-05-31-data.csv')
# view_count = data['view_count']
# likes = data['likes']
# ratio = data['ratio']

# plt.title('Trending YouTube Videos')
# plt.xlabel('View Count')
# plt.ylabel('Total Likes')

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Use color based on sizes to add additional information
# Let's assume that consumers' rating is scored on the sacle of 1 to 10 according to their satisfaction to a product

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]

# plt.scatter (x, y, s=100, c='green', marker='x')
plt.scatter (x, y, s=100, c=colors, edgecolor='black', linewidth=1, alpha=0.75)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Use colormap instead of using shades of grey in the above graph
# [ref. of colormap](https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html)

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]

# plt.scatter (x, y, s=100, c='green', marker='x')
plt.scatter (x, y, s=100, c=colors, cmap='Greens', edgecolor='black', linewidth=1, alpha=0.75)


plt.tight_layout()

plt.show()

# %% [markdown]
# ## Add a label for the color map to inform that what these colors represent
# Add a color bar legend

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]

# plt.scatter (x, y, s=100, c='green', marker='x')
plt.scatter (x, y, s=100, c=colors, cmap='Greens', edgecolor='black', linewidth=1, alpha=0.75)

cbar=plt.colorbar()
cbar.set_label('Satisfaction')

plt.tight_layout()

plt.show()
# Out:
# C:\Users\Kwang-Chul Kwon\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   del sys.path[0]

# %% [markdown]
# ## Change the sizes of data points

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]
sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174,
         538, 239, 394, 399, 153, 273, 293, 436, 501, 397, 539]

plt.scatter (x, y, s=sizes, c=colors, cmap='Greens', edgecolor='black', linewidth=1, alpha=0.75)

cbar=plt.colorbar()
cbar.set_label('Satisfaction')

plt.tight_layout()

plt.show()
# Out:
# C:\Users\Kwang-Chul Kwon\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.

# %% [markdown]
# ## Analysis the top 200 trending videos on YouTube using scatter plot

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

data = pd.read_csv('./data/2019-05-31-data.csv')
data.head()
# Out:
#    view_count   likes  ratio
# 0     8036001  324742  96.91
# 1     9378067  562589  98.19
# 2     2182066  273650  99.38
# 3     6525864   94698  96.25
# 4     9481284  582481  97.22

# %%
# %config InlineBackend.figure_formats=['svg']

view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

plt.scatter(view_count, likes, edgecolor='black', linewidth=1, alpha=0.75)

plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### In the above graph, we can find one point that is located far away from most of points but that is a meaningful point so, in this case, we can use logscale to lessen the outlier to skew the plot.

# %%
# %config InlineBackend.figure_formats=['svg']

view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

plt.scatter(view_count, likes, c=ratio, cmap='summer',
            edgecolor='black', linewidth=1, alpha=0.75)
cbar = plt.colorbar()
cbar.set_label('Like/Dislike Ratio')

plt.xscale('log')
plt.yscale('log')
plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Kwang-Chul Kwon\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   if __name__ == '__main__':

# %% [markdown]
# ## Analysis of population distribution of CA using scatter plot

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./data/california_cities.csv')
df.head()
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'

lat, long=df['latd'], df['longd']
area, population=df['area_total_sq_mi'], df['population_total']

fig, ax=plt.subplots(figsize=(12, 6))
ax.scatter(lat, long, c=np.log10(population), s=area, cmap='viridis')

cmap=plt.get_cmap('viridis', 20)
norm=mpl.colors.Normalize(vmin=0, vmax=2)
sm=plt.cm.ScalarMappable(cmap=cmap, norm=norm)
plt.colorbar(sm, ticks=np.linspace(0, 2, 20), boundaries=np.arange(0.05, 2.1, 0.1), label='log$_{10}$(population)')

for i in [100, 300, 500]:
    ax.scatter([], [], s=i, c='k', alpha=0.2, label=str(i)+ ' km$^2$')
    
leg=ax.legend(scatterpoints=1, frameon=False, fontsize= 12, labelspacing=1, borderpad=2)
leg.set_title('City Area', prop={'size': 20})

for label in ax.get_xticklabels():
    label.set_ha('center')
    label.set_fontsize(15)
#     label.set_rotation(45)

for label in ax.get_yticklabels():
    label.set_fontsize(15)
    
ax.set_xlabel('Latitude', fontsize=20)
ax.set_ylabel('Longitude', fontsize=20)
ax.yaxis.set_label_coords(-0.1, 0.5)
    
plt.suptitle('\n'.join(['Populatoin of City', 'California', '2021 Census']), fontsize=20,x=0.45, y=1.02)
# Out:
# C:\Users\Kwang-Chul Kwon\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   del sys.path[0]
# Text(0.45, 1.02, 'Populatoin of City\nCalifornia\n2021 Census')

# %% [markdown]
# ### sns.scatter

# %%
import matplotlib.pyplot as plt
import numpy as np; np.random.seed(42)
import matplotlib.ticker as ticker
import seaborn as sns
import pandas as pd

df=pd.DataFrame({'x':np.random.randint(50000, 250000, size=20),
               'y':np.random.randint(7,15, size=20),
               'col':np.random.choice(list('ABC'), size=20)})
print(df)
sns.set()
fig, ax=plt.subplots(figsize=(8,5))
palette=sns.color_palette('bright', 3)
sns.scatterplot(ax=ax, x='x', y='y', hue='col', data=df, palette=palette, s=200, marker='o')
ax.legend(bbox_to_anchor=(1,1), ncol=1)
ax.set(xlim=(50000, 250000))
xlabels=[f'{x:,.2f}K'for x in ax.get_xticks()/1000]
# xlabels=['{:,.2f}K'.format(x) for x in ax.get_xticks()/1000]
ax.set_xticklabels(xlabels)
plt.show()
# Out:
#          x   y col
# 0   171958  10   C
# 1   196867  12   B
# 2   181932  12   B
# 3   153694   8   C
# 4   169879  14   B
# 5   160268  10   C
# 6   104886  11   C
# 7   187337   7   A
# 8   218266  10   C
# 9   137498   8   A
# 10  162727  12   C
# 11  176324  11   C
# 12  225203  10   A
# 13  241335   7   A
# 14   66023   7   C
# 15   91090   9   B
# 16  117221   9   A
# 17  114820  13   B
# 18   50769   8   B
# 19  109735  14   B
# C:\Users\Kwang-Chul Kwon\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
