# %%
# %load command1.py
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity='all'

# %config InlineBackend.figure_format='svg'
plt.rcParams['figure.dpi']=120

pd.options.display.float_format='{:,.2f}'.format
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## A simple categorical heatmap
#
# - 2D array data
# - labesl for x and y each
# - heatmap itsel is an `imshow` plot with the labesl set to the categories we have
#
# **It is important to set both, the tick locations (set_xticks) as well as the tick labels (set_xticklabels), otherwise they would become out of sync,**

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots(figsize=(8, 8))
im = ax.imshow(harvest)



# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(farmers)), labels=farmers)
ax.set_yticks(np.arange(len(vegetables)), labels=vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()
# Out:
# ...
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
# Text(0.5, 1.0, 'Harvest of local farmers (in tons/year)')

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots(figsize=(8, 8))
# im = ax.imshow(harvest)

ax=sns.heatmap(harvest,cmap='Greens', annot=True, cbar=False,xticklabels=True, yticklabels=True)
# Show all ticks and label them with the respective list entries
# ax.set_xticks(np.arange(len(farmers)), labels=farmers)
# ax.set_yticks(np.arange(len(vegetables)), labels=vegetables)

ax.set_xticklabels(farmers, fontsize=12, rotation=45, ha='right')
ax.set_yticklabels(vegetables, fontsize=12, rotation=360)

# Rotate the tick labels and set their alignment.
# plt.setp(ax.get_xticklabels(), rotation=-45, ha="right")
# plt.setp(ax.get_yticklabels(), va='center')

# # Loop over data dimensions and create text annotations.
# for i in range(len(vegetables)):
#     for j in range(len(farmers)):
#         text = ax.text(j, i, harvest[i, j],
#                        ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()
# Out:
# [Text(0.5, 0, 'Farmer Joe'),
#  Text(1.5, 0, 'Upland Bros.'),
#  Text(2.5, 0, 'Smith Gardening'),
#  Text(3.5, 0, 'Agrifun'),
#  Text(4.5, 0, 'Organiculture'),
#  Text(5.5, 0, 'BioGoods Ltd.'),
#  Text(6.5, 0, 'Cornylee Corp.')]
# [Text(0, 0.5, 'cucumber'),
#  Text(0, 1.5, 'tomato'),
#  Text(0, 2.5, 'lettuce'),
#  Text(0, 3.5, 'asparagus'),
#  Text(0, 4.5, 'potato'),
#  Text(0, 5.5, 'wheat'),
#  Text(0, 6.5, 'barley')]
# Text(0.5, 1.0, 'Harvest of local farmers (in tons/year)')
