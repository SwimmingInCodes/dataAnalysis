# %% [markdown]
# # Websrapping and storing into a json file
#
# - Webscrap the info of books from a webpage which consists of 50 pages and each pahge contains the info of 20 books
# - First, webscape the book info from a single webpage and store it into a json file
# - Then, webscrape all the book info from the 50 webpages and store them into a json file

# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint
import csv
import json

# %% [markdown]
# **Snippet for the testing codes**

# %% [markdown]
# ```python
# import json
#
# with open('total_book_info.json', 'w') as f:
#     json.dump(results, f)
#
# with open('total_book_info.json') as f:
#     total_book=json.load(f)
#     print(json.dumps(total_book, indent=2))
# ```

# %% [markdown]
# ## Collect data from a single webpage

# %%
url = 'https://books.toscrape.com/'
def clean (item):
    return item.strip().replace('£', '').replace('Â', '')

def get_page(url):
    r=requests.get(url)
    soup=BeautifulSoup(r.text, 'lxml')
    return soup

def parse_soup(soup):
    books_list=[]
    books=soup.find_all('article', class_='product_pod')

    for book in books:
        book_list={}
        
        title=book.h3.a.text
        price=float(clean(book.find('p', class_='price_color').text))
        stock=clean(book.find('p', class_='instock availability').text)

        book_list['Title']=title
        book_list['Price']=price
        book_list['Stock']=stock

        books_list.append(book_list)
    return books_list


soup=get_page(url)
book_list=parse_soup(soup)

pprint(book_list)
# Out:
# [{'Price': 51.77, 'Stock': 'In stock', 'Title': 'A Light in the ...'},
#  {'Price': 53.74, 'Stock': 'In stock', 'Title': 'Tipping the Velvet'},
#  {'Price': 50.1, 'Stock': 'In stock', 'Title': 'Soumission'},
#  {'Price': 47.82, 'Stock': 'In stock', 'Title': 'Sharp Objects'},
#  {'Price': 54.23, 'Stock': 'In stock', 'Title': 'Sapiens: A Brief History ...'},
#  {'Price': 22.65, 'Stock': 'In stock', 'Title': 'The Requiem Red'},
#  {'Price': 33.34, 'Stock': 'In stock', 'Title': 'The Dirty Little Secrets ...'},
#  {'Price': 17.93, 'Stock': 'In stock', 'Title': 'The Coming Woman: A ...'},
#  {'Price': 22.6, 'Stock': 'In stock', 'Title': 'The Boys in the ...'},
#  {'Price': 52.15, 'Stock': 'In stock', 'Title': 'The Black Maria'},
#  {'Price': 13.99,
#   'Stock': 'In stock',
#   'Title': 'Starving Hearts (Triangular Trade ...'},
#  {'Price': 20.66, 'Stock': 'In stock', 'Title': "Shakespeare's Sonnets"},
#  {'Price': 17.46, 'Stock': 'In stock', 'Title': 'Set Me Free'},
#  {'Price': 52.29,
#   'Stock': 'In stock',
#   'Title': "Scott Pilgrim's Precious Little ..."},
#  {'Price': 35.02, 'Stock': 'In stock', 'Title': 'Rip it Up and ...'},
#  {'Price': 57.25, 'Stock': 'In stock', 'Title': 'Our Band Could Be ...'},
#  {'Price': 23.88, 'Stock': 'In stock', 'Title': 'Olio'},
#  {'Price': 37.59,
#   'Stock': 'In stock',
#   'Title': 'Mesaerion: The Best Science ...'},
#  {'Price': 51.33, 'Stock': 'In stock', 'Title': 'Libertarianism for Beginners'},
#  {'Price': 45.17, 'Stock': 'In stock', 'Title': "It's Only the Himalayas"}]

# %% [markdown]
# **Store the data into a json file**

# %%
with open('book_info.json', 'w') as f:
    json.dump(book_list, f)

# %% [markdown]
# **Open the json file and confirm the data**

# %%
with open('book_info.json', 'r') as f:
    data=json.load(f)
    
    print(json.dumps(data, indent=2))
# Out:
# [
#   {
#     "Title": "A Light in the ...",
#     "Price": 51.77,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Tipping the Velvet",
#     "Price": 53.74,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Soumission",
#     "Price": 50.1,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Sharp Objects",
#     "Price": 47.82,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Sapiens: A Brief History ...",
#     "Price": 54.23,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "The Requiem Red",
#     "Price": 22.65,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "The Dirty Little Secrets ...",
#     "Price": 33.34,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "The Coming Woman: A ...",
#     "Price": 17.93,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "The Boys in the ...",
#     "Price": 22.6,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "The Black Maria",
#     "Price": 52.15,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Starving Hearts (Triangular Trade ...",
#     "Price": 13.99,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Shakespeare's Sonnets",
#     "Price": 20.66,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Set Me Free",
#     "Price": 17.46,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Scott Pilgrim's Precious Little ...",
#     "Price": 52.29,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Rip it Up and ...",
#     "Price": 35.02,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Our Band Could Be ...",
#     "Price": 57.25,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Olio",
#     "Price": 23.88,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Mesaerion: The Best Science ...",
#     "Price": 37.59,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "Libertarianism for Beginners",
#     "Price": 51.33,
#     "Stock": "In stock"
#   },
#   {
#     "Title": "It's Only the Himalayas",
#     "Price": 45.17,
#     "Stock": "In stock"
#   }
# ]

# %% [markdown]
# <h2> Collecting all the data from 50 webpages </h2>

# %% [markdown]
# <h3> Analyse the web url </3>

# %% [markdown]
# - When webpage moves to next page, only the nubmer chanes so we can put that number into a variable
#
# https://books.toscrape.com/catalogue/page-1.html <br>
# https://books.toscrape.com/catalogue/page-2.html
#
#                     .
#
#                     .
#
#                     .
#
# https://books.toscrape.com/catalogue/page-50.html

# %%
# no pagination in this example

# url = f'https://books.toscrape.com/catalogue/page-{i}.html'

import time


page_num=3 # Control the number of webpages from which we will collect data

def clean (item):
    return item.strip().replace('£', '').replace('Â', '')

def retrieve_all(page_num):
    total_book_list=[]
    for i in range(page_num):
        url = f'https://books.toscrape.com/catalogue/page-{i+1}.html' # i starts with 0 so we shoudl add 1 to it
        print(url)
        
        def get_page(url):
            r=requests.get(url)
            soup=BeautifulSoup(r.text, 'lxml')
            return soup

        soup=get_page(url)
        
        def parse_soup(soup):
            books_list=[]
            books=soup.find_all('article', class_='product_pod')
            
            for book in books:
                book_list={}
                
                title=book.h3.a.text
                price=float(clean(book.find('p', class_='price_color').text))
                stock=clean(book.find('p', class_='instock availability').text)

                book_list['Title']=title
                book_list['Price']=price
                book_list['Stock']=stock
                print(book_list)
                
                books_list.append(book_list)
            return books_list
    
        total_book_list.append(parse_soup(soup)) 

        time.sleep(0.5)  
    
    return total_book_list

results=retrieve_all(page_num)
# Out:
# https://books.toscrape.com/catalogue/page-1.html
# {'Title': 'A Light in the ...', 'Price': 51.77, 'Stock': 'In stock'}
# {'Title': 'Tipping the Velvet', 'Price': 53.74, 'Stock': 'In stock'}
# {'Title': 'Soumission', 'Price': 50.1, 'Stock': 'In stock'}
# {'Title': 'Sharp Objects', 'Price': 47.82, 'Stock': 'In stock'}
# {'Title': 'Sapiens: A Brief History ...', 'Price': 54.23, 'Stock': 'In stock'}
# {'Title': 'The Requiem Red', 'Price': 22.65, 'Stock': 'In stock'}
# {'Title': 'The Dirty Little Secrets ...', 'Price': 33.34, 'Stock': 'In stock'}
# {'Title': 'The Coming Woman: A ...', 'Price': 17.93, 'Stock': 'In stock'}
# {'Title': 'The Boys in the ...', 'Price': 22.6, 'Stock': 'In stock'}
# {'Title': 'The Black Maria', 'Price': 52.15, 'Stock': 'In stock'}
# {'Title': 'Starving Hearts (Triangular Trade ...', 'Price': 13.99, 'Stock': 'In stock'}
# {'Title': "Shakespeare's Sonnets", 'Price': 20.66, 'Stock': 'In stock'}
# {'Title': 'Set Me Free', 'Price': 17.46, 'Stock': 'In stock'}
# {'Title': "Scott Pilgrim's Precious Little ...", 'Price': 52.29, 'Stock': 'In stock'}
# {'Title': 'Rip it Up and ...', 'Price': 35.02, 'Stock': 'In stock'}
# {'Title': 'Our Band Could Be ...', 'Price': 57.25, 'Stock': 'In stock'}
# {'Title': 'Olio', 'Price': 23.88, 'Stock': 'In stock'}
# {'Title': 'Mesaerion: The Best Science ...', 'Price': 37.59, 'Stock': 'In stock'}
# {'Title': 'Libertarianism for Beginners', 'Price': 51.33, 'Stock': 'In stock'}
# {'Title': "It's Only the Himalayas", 'Price': 45.17, 'Stock': 'In stock'}
# https://books.toscrape.com/catalogue/page-2.html
# {'Title': 'In Her Wake', 'Price': 12.84, 'Stock': 'In stock'}
# {'Title': 'How Music Works', 'Price': 37.32, 'Stock': 'In stock'}
# {'Title': 'Foolproof Preserving: A Guide ...', 'Price': 30.52, 'Stock': 'In stock'}
# {'Title': 'Chase Me (Paris Nights ...', 'Price': 25.27, 'Stock': 'In stock'}
# {'Title': 'Black Dust', 'Price': 34.53, 'Stock': 'In stock'}
# {'Title': 'Birdsong: A Story in ...', 'Price': 54.64, 'Stock': 'In stock'}
# {'Title': "America's Cradle of Quarterbacks: ...", 'Price': 22.5, 'Stock': 'In stock'}
# {'Title': 'Aladdin and His Wonderful ...', 'Price': 53.13, 'Stock': 'In stock'}
# {'Title': 'Worlds Elsewhere: Journeys Around ...', 'Price': 40.3, 'Stock': 'In stock'}
# {'Title': 'Wall and Piece', 'Price': 44.18, 'Stock': 'In stock'}
# {'Title': 'The Four Agreements: A ...', 'Price': 17.66, 'Stock': 'In stock'}
# {'Title': 'The Five Love Languages: ...', 'Price': 31.05, 'Stock': 'In stock'}
# {'Title': 'The Elephant Tree', 'Price': 23.82, 'Stock': 'In stock'}
# {'Title': 'The Bear and the ...', 'Price': 36.89, 'Stock': 'In stock'}
# {'Title': "Sophie's World", 'Price': 15.94, 'Stock': 'In stock'}
# {'Title': 'Penny Maybe', 'Price': 33.29, 'Stock': 'In stock'}
# {'Title': 'Maude (1883-1993):She Grew Up ...', 'Price': 18.02, 'Stock': 'In stock'}
# {'Title': 'In a Dark, Dark ...', 'Price': 19.63, 'Stock': 'In stock'}
# {'Title': 'Behind Closed Doors', 'Price': 52.22, 'Stock': 'In stock'}
# {'Title': "You can't bury them ...", 'Price': 33.63, 'Stock': 'In stock'}
# https://books.toscrape.com/catalogue/page-3.html
# {'Title': 'Slow States of Collapse: ...', 'Price': 57.31, 'Stock': 'In stock'}
# {'Title': 'Reasons to Stay Alive', 'Price': 26.41, 'Stock': 'In stock'}
# {'Title': 'Private Paris (Private #10)', 'Price': 47.61, 'Stock': 'In stock'}
# {'Title': '#HigherSelfie: Wake Up Your ...', 'Price': 23.11, 'Stock': 'In stock'}
# {'Title': 'Without Borders (Wanderlove #1)', 'Price': 45.07, 'Stock': 'In stock'}
# {'Title': 'When We Collided', 'Price': 31.77, 'Stock': 'In stock'}
# {'Title': 'We Love You, Charlie ...', 'Price': 50.27, 'Stock': 'In stock'}
# {'Title': 'Untitled Collection: Sabbath Poems ...', 'Price': 14.27, 'Stock': 'In stock'}
# {'Title': 'Unseen City: The Majesty ...', 'Price': 44.18, 'Stock': 'In stock'}
# {'Title': 'Unicorn Tracks', 'Price': 18.78, 'Stock': 'In stock'}
# {'Title': 'Unbound: How Eight Technologies ...', 'Price': 25.52, 'Stock': 'In stock'}
# {'Title': 'Tsubasa: WoRLD CHRoNiCLE 2 ...', 'Price': 16.28, 'Stock': 'In stock'}
# {'Title': 'Throwing Rocks at the ...', 'Price': 31.12, 'Stock': 'In stock'}
# {'Title': 'This One Summer', 'Price': 19.49, 'Stock': 'In stock'}
# {'Title': 'Thirst', 'Price': 17.27, 'Stock': 'In stock'}
# {'Title': 'The Torch Is Passed: ...', 'Price': 19.09, 'Stock': 'In stock'}
# {'Title': 'The Secret of Dreadwillow ...', 'Price': 56.13, 'Stock': 'In stock'}
# {'Title': 'The Pioneer Woman Cooks: ...', 'Price': 56.41, 'Stock': 'In stock'}
# {'Title': 'The Past Never Ends', 'Price': 56.5, 'Stock': 'In stock'}
# {'Title': 'The Natural History of ...', 'Price': 45.22, 'Stock': 'In stock'}

# %%
import json

with open('total_book_info.json', 'w') as f:
    json.dump(results, f)

# %%
with open('total_book_info.json') as f:
    total_book=json.load(f)
    
    print(json.dumps(total_book, indent=2))
# Out:
# [
#   [
#     {
#       "Title": "A Light in the ...",
#       "Price": 51.77,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Tipping the Velvet",
#       "Price": 53.74,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Soumission",
#       "Price": 50.1,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Sharp Objects",
#       "Price": 47.82,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Sapiens: A Brief History ...",
#       "Price": 54.23,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Requiem Red",
#       "Price": 22.65,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Dirty Little Secrets ...",
#       "Price": 33.34,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Coming Woman: A ...",
#       "Price": 17.93,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Boys in the ...",
#       "Price": 22.6,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Black Maria",
#       "Price": 52.15,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Starving Hearts (Triangular Trade ...",
#       "Price": 13.99,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Shakespeare's Sonnets",
#       "Price": 20.66,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Set Me Free",
#       "Price": 17.46,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Scott Pilgrim's Precious Little ...",
#       "Price": 52.29,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Rip it Up and ...",
#       "Price": 35.02,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Our Band Could Be ...",
#       "Price": 57.25,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Olio",
#       "Price": 23.88,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Mesaerion: The Best Science ...",
#       "Price": 37.59,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Libertarianism for Beginners",
#       "Price": 51.33,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "It's Only the Himalayas",
#       "Price": 45.17,
#       "Stock": "In stock"
#     }
#   ],
#   [
#     {
#       "Title": "In Her Wake",
#       "Price": 12.84,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "How Music Works",
#       "Price": 37.32,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Foolproof Preserving: A Guide ...",
#       "Price": 30.52,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Chase Me (Paris Nights ...",
#       "Price": 25.27,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Black Dust",
#       "Price": 34.53,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Birdsong: A Story in ...",
#       "Price": 54.64,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "America's Cradle of Quarterbacks: ...",
#       "Price": 22.5,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Aladdin and His Wonderful ...",
#       "Price": 53.13,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Worlds Elsewhere: Journeys Around ...",
#       "Price": 40.3,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Wall and Piece",
#       "Price": 44.18,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Four Agreements: A ...",
#       "Price": 17.66,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Five Love Languages: ...",
#       "Price": 31.05,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Elephant Tree",
#       "Price": 23.82,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Bear and the ...",
#       "Price": 36.89,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Sophie's World",
#       "Price": 15.94,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Penny Maybe",
#       "Price": 33.29,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Maude (1883-1993):She Grew Up ...",
#       "Price": 18.02,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "In a Dark, Dark ...",
#       "Price": 19.63,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Behind Closed Doors",
#       "Price": 52.22,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "You can't bury them ...",
#       "Price": 33.63,
#       "Stock": "In stock"
#     }
#   ],
#   [
#     {
#       "Title": "Slow States of Collapse: ...",
#       "Price": 57.31,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Reasons to Stay Alive",
#       "Price": 26.41,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Private Paris (Private #10)",
#       "Price": 47.61,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "#HigherSelfie: Wake Up Your ...",
#       "Price": 23.11,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Without Borders (Wanderlove #1)",
#       "Price": 45.07,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "When We Collided",
#       "Price": 31.77,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "We Love You, Charlie ...",
#       "Price": 50.27,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Untitled Collection: Sabbath Poems ...",
#       "Price": 14.27,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Unseen City: The Majesty ...",
#       "Price": 44.18,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Unicorn Tracks",
#       "Price": 18.78,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Unbound: How Eight Technologies ...",
#       "Price": 25.52,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Tsubasa: WoRLD CHRoNiCLE 2 ...",
#       "Price": 16.28,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Throwing Rocks at the ...",
#       "Price": 31.12,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "This One Summer",
#       "Price": 19.49,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "Thirst",
#       "Price": 17.27,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Torch Is Passed: ...",
#       "Price": 19.09,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Secret of Dreadwillow ...",
#       "Price": 56.13,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Pioneer Woman Cooks: ...",
#       "Price": 56.41,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Past Never Ends",
#       "Price": 56.5,
#       "Stock": "In stock"
#     },
#     {
#       "Title": "The Natural History of ...",
#       "Price": 45.22,
#       "Stock": "In stock"
#     }
#   ]
# ]
