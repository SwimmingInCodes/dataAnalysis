# %%
# %load command1.py
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity='all'

# %config InlineBackend.figure_format='svg'
plt.rcParams['figure.dpi']=120

pd.options.display.float_format='{:,.2f}'.format
pd.set_option('display.max_colwidth', None)

# %%
df_customer = pd.DataFrame({
    'id': [1,2,3,4],
    'name': ['Tom', 'Jenny', 'James', 'Dan'],
})
df_customer
# Out:
#    id   name
# 0   1    Tom
# 1   2  Jenny
# 2   3  James
# 3   4    Dan

# %%
df_info = pd.DataFrame({
    'id': [2,3,4,5],
    'age': [31,20,40,70],
    'sex': ['F', 'M', 'M', 'F']
})
df_info
# Out:
#    id  age sex
# 0   2   31   F
# 1   3   20   M
# 2   4   40   M
# 3   5   70   F

# %%
# without any key column
pd.merge(df_customer, df_info)
df_customer.merge(df_info)
# Out:
#    id   name  age sex
# 0   2  Jenny   31   F
# 1   3  James   20   M
# 2   4    Dan   40   M
#    id   name  age sex
# 0   2  Jenny   31   F
# 1   3  James   20   M
# 2   4    Dan   40   M

# %%
# specigying key columns using arguemnt on

pd.merge(df_customer, df_info, on = 'id')
# Out:
#    id   name  age sex
# 0   2  Jenny   31   F
# 1   3  James   20   M
# 2   4    Dan   40   M

# %%
# with multiple key columns
df_order = pd.DataFrame({
    'id': [2,3,4,5],
    'name': ['Jenny', 'James', 'Dan', 'leo'],
    'quantity': [2,4,6,10]
})


pd.merge(df_customer, df_order, on=['id','name'])
# Out:
#    id   name  quantity
# 0   2  Jenny         2
# 1   3  James         4
# 2   4    Dan         6

# %%
# using left_on and right_on
df_info_2 = pd.DataFrame({
    'customer_id': [2,3,4,5],
    'age': [31,20,40,70],
    'sex': ['F', 'M', 'M', 'F']
})
df_info_2
# Out:
#    customer_id  age sex
# 0            2   31   F
# 1            3   20   M
# 2            4   40   M
# 3            5   70   F

# %%
df_customer
# Out:
#    id   name
# 0   1    Tom
# 1   2  Jenny
# 2   3  James
# 3   4    Dan

# %%
pd.merge(df_customer, df_info_2, left_on='id', right_on='customer_id')
# Out:
#    id   name  customer_id  age sex
# 0   2  Jenny            2   31   F
# 1   3  James            3   20   M
# 2   4    Dan            4   40   M

# %%
# join option how

df_customer = pd.DataFrame({
    'id': [1,2,3,4],
    'name': ['Tom', 'Jenny', 'James', 'Dan'],
})

df_customer

df_info = pd.DataFrame({
    'id': [2,3,4,5],
    'age': [31,20,40,70],
    'sex': ['F', 'M', 'M', 'F']
})

df_info
# Out:
#    id   name
# 0   1    Tom
# 1   2  Jenny
# 2   3  James
# 3   4    Dan
#    id  age sex
# 0   2   31   F
# 1   3   20   M
# 2   4   40   M
# 3   5   70   F

# %%
# inner
pd.merge(df_customer, df_info, how='inner', on='id') # pd.merge(df_customer, df_info, on='id')
# left
pd.merge(df_customer, df_info, how='left', on='id')
# right
pd.merge(df_customer, df_info, how='right', on='id')
# outer
pd.merge(df_customer, df_info, how='outer', on='id')
# Out:
#    id   name  age sex
# 0   2  Jenny   31   F
# 1   3  James   20   M
# 2   4    Dan   40   M
#    id   name   age  sex
# 0   1    Tom   NaN  NaN
# 1   2  Jenny 31.00    F
# 2   3  James 20.00    M
# 3   4    Dan 40.00    M
#    id   name  age sex
# 0   2  Jenny   31   F
# 1   3  James   20   M
# 2   4    Dan   40   M
# 3   5    NaN   70   F
#    id   name   age  sex
# 0   1    Tom   NaN  NaN
# 1   2  Jenny 31.00    F
# 2   3  James 20.00    M
# 3   4    Dan 40.00    M
# 4   5    NaN 70.00    F

# %%
# Using validate to avoid invalid records
df_customer = pd.DataFrame({
    'id': [1,2,3,4],
    'name': ['Tom', 'Jenny', 'James', 'Dan'],
})
df_customer

df_order_2 = pd.DataFrame({
    'id': [2,2,4,4],
    'product': ['A', 'B' ,'A', 'C'],
    'quantity': [31, 21, 20,40],
    'date': pd.date_range('2019-02-24', periods=4, freq='D')
})
df_order_2
# Out:
#    id   name
# 0   1    Tom
# 1   2  Jenny
# 2   3  James
# 3   4    Dan
#    id product  quantity       date
# 0   2       A        31 2019-02-24
# 1   2       B        21 2019-02-25
# 2   4       A        20 2019-02-26
# 3   4       C        40 2019-02-27

# %%
pd.merge(df_customer, df_order_2, how='left', on='id')
# Out:
#    id   name product  quantity       date
# 0   1    Tom     NaN       NaN        NaT
# 1   2  Jenny       A     31.00 2019-02-24
# 2   2  Jenny       B     21.00 2019-02-25
# 3   3  James     NaN       NaN        NaT
# 4   4    Dan       A     20.00 2019-02-26
# 5   4    Dan       C     40.00 2019-02-27

# %%
df_customer = pd.DataFrame({
    'id': [1,2,3,4],
    'name': ['Tom', 'Jenny', 'James', 'Dan'],
})


df_info = pd.DataFrame({
    'id': [2,2,3,4,5],
    'age': [31,21, 20,40,70],
    'sex': ['F', 'F' ,'M', 'M', 'F']
})

pd.merge(df_customer, df_info, how='left', on='id')
# Out:
#    id   name   age  sex
# 0   1    Tom   NaN  NaN
# 1   2  Jenny 31.00    F
# 2   2  Jenny 21.00    F
# 3   3  James 20.00    M
# 4   4    Dan 40.00    M

# %%
pd.merge(df_customer, df_info, how='left', on='id', validate='1:1')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21736\3828162681.py in <module>
# ----> 1 pd.merge(df_customer, df_info, how='left', on='id', validate='1:1')
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     707         # are in fact unique.
#     708         if validate is not None:
# --> 709             self._validate(validate)
#     710
#     711     def get_result(self) -> DataFrame:
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate(self, validate)
#    1428             elif not right_unique:
#    1429                 raise MergeError(
# -> 1430                     "Merge keys are not unique in right dataset; not a one-to-one merge"
#    1431                 )
#    1432
#
# MergeError: Merge keys are not unique in right dataset; not a one-to-one merge
