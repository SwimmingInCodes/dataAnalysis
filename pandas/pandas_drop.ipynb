# %%
# %load command.py

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity='all'

# %config InlineBackend.figure_format='svg'
plt.rcParams['figure.dpi']=120

pd.options.display.float_format='{:,.2f}'.format
pd.set_option('display.max_colwidth', None)

# %%
# %%writefile command1.py
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity='all'

%config InlineBackend.figure_format='svg'
plt.rcParams['figure.dpi']=120

pd.options.display.float_format='{:,.2f}'.format
pd.set_option('display.max_colwidth', None)
# Out:
# Writing command1.py

# %%
# %load command1.py
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity='all'

# %config InlineBackend.figure_format='svg'
plt.rcParams['figure.dpi']=120

pd.options.display.float_format='{:,.2f}'.format
pd.set_option('display.max_colwidth', None)

# %%
print('numpy', np.__version__)
print('pandas', pd.__version__)
# Out:
# numpy 1.21.5
# pandas 1.3.5

# %%
df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'math': [60,89,82,70],
    'physics': [66,95,83,66],
    'chemistry': [61,91,77,70]
})
df
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 1    B    89       95         91
# 2    C    82       83         77
# 3    D    70       66         70

# %%
# delete a single row
df.drop(1)
df.drop(labels=1)
df.drop(index=1)
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 2    C    82       83         77
# 3    D    70       66         70
#   name  math  physics  chemistry
# 0    A    60       66         61
# 2    C    82       83         77
# 3    D    70       66         70
#   name  math  physics  chemistry
# 0    A    60       66         61
# 2    C    82       83         77
# 3    D    70       66         70

# %%
# delete multiple rows
df.drop([1,2])
df.drop(labels=[1,2])
df.drop(index=[1,2])
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 3    D    70       66         70
#   name  math  physics  chemistry
# 0    A    60       66         61
# 3    D    70       66         70
#   name  math  physics  chemistry
# 0    A    60       66         61
# 3    D    70       66         70

# %%
# 3. Delete rows based on row position and cusotm range
df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'math': [60,89,82,70],
    'physics': [66,95,83,66],
    'chemistry': [61,91,77,70]
}, index=['A0', 'A1', 'A2', 'A3'])
df
# Out:
#    name  math  physics  chemistry
# A0    A    60       66         61
# A1    B    89       95         91
# A2    C    82       83         77
# A3    D    70       66         70

# %%
df.drop(index=df.index[1])
df.drop(index=df.index[-1])
df.drop(index=df.index[-2:])
df.drop(index=df.index[::2])
# Out:
#    name  math  physics  chemistry
# A0    A    60       66         61
# A2    C    82       83         77
# A3    D    70       66         70
#    name  math  physics  chemistry
# A0    A    60       66         61
# A1    B    89       95         91
# A2    C    82       83         77
#    name  math  physics  chemistry
# A0    A    60       66         61
# A1    B    89       95         91
#    name  math  physics  chemistry
# A1    B    89       95         91
# A3    D    70       66         70

# %%
# delete a column
df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'math': [60,89,82,70],
    'physics': [66,95,83,66],
    'chemistry': [61,91,77,70]
})
df
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 1    B    89       95         91
# 2    C    82       83         77
# 3    D    70       66         70

# %%
df.drop('math', axis=1)
df.drop(labels='math', axis=1)
df.drop(columns='math')
# Out:
#   name  physics  chemistry
# 0    A       66         61
# 1    B       95         91
# 2    C       83         77
# 3    D       66         70
#   name  physics  chemistry
# 0    A       66         61
# 1    B       95         91
# 2    C       83         77
# 3    D       66         70
#   name  physics  chemistry
# 0    A       66         61
# 1    B       95         91
# 2    C       83         77
# 3    D       66         70

# %%
# delete multiple columns

df.drop(['math', 'physics'], axis=1)
df.drop(labels=['math', 'physics'], axis=1)
df.drop(columns=['math', 'physics'])
# Out:
#   name  chemistry
# 0    A         61
# 1    B         91
# 2    C         77
# 3    D         70
#   name  chemistry
# 0    A         61
# 1    B         91
# 2    C         77
# 3    D         70
#   name  chemistry
# 0    A         61
# 1    B         91
# 2    C         77
# 3    D         70

# %%
# delete columns based on column position and custom range

df.drop(columns=df.columns[1])
df.drop(columns=df.columns[-1])
df.drop(columns=df.columns[-2:])
df.drop(columns=df.columns[::2])
# Out:
#   name  physics  chemistry
# 0    A       66         61
# 1    B       95         91
# 2    C       83         77
# 3    D       66         70
#   name  math  physics
# 0    A    60       66
# 1    B    89       95
# 2    C    82       83
# 3    D    70       66
#   name  math
# 0    A    60
# 1    B    89
# 2    C    82
# 3    D    70
#    math  chemistry
# 0    60         61
# 1    89         91
# 2    82         77
# 3    70         70

# %%
# working with multiindex
import pandas as pd
from pandas import IndexSlice as idx 

df=pd.read_csv('dataset.csv')
df.head()
# Out:
#   Unnamed: 0  Unnamed: 1                Day      Day.1            Day.2  \
# 0        NaN         NaN            Weather       Wind  Max Temperature
# 1       City        Date                NaN        NaN              NaN
# 2     London  2019-07-01             Shower  SW 16 mph               28
# 3     London  2019-07-02             Shower  SW 16 mph               29
# 4     London  2019-07-03  Scattered showers  SW 16 mph               29
#
#         Night    Night.1          Night.2
# 0     Weather       Wind  Max Temperature
# 1         NaN        NaN              NaN
# 2      Shower  SW 16 mph               18
# 3  Heavy rain  SW 16 mph               17
# 4  Heavy rain  SW 16 mph               19

# %%
df = pd.read_csv('dataset.csv',
    index_col=[0,1],
    header=[0,1]
)
df=df.sort_index()
df
# Out:
#                                     Day                             \
#                                 Weather       Wind Max Temperature
# City      Date
# Cambridge 2019-07-01             Shower  SW 16 mph              24
#           2019-07-02  Scattered showers   E 20 mph              21
#           2019-07-03  Scattered showers  SE 10 mph              22
#           2019-07-04             Shower   S 25 mph              22
# London    2019-07-01             Shower  SW 16 mph              28
#           2019-07-02             Shower  SW 16 mph              29
#           2019-07-03  Scattered showers  SW 16 mph              29
#           2019-07-04      Mostly cloudy  SW 16 mph              31
# Oxford    2019-07-01             Shower  SW 13 mph              25
#           2019-07-02             Shower  SW 16 mph              26
#           2019-07-03  Scattered showers  SW 16 mph              28
#           2019-07-04             Shower  SW 14 mph              25
#
#                                   Night
#                                 Weather       Wind Max Temperature
# City      Date
# Cambridge 2019-07-01             Shower  SW 16 mph              17
#           2019-07-02  Scattered showers   E 20 mph              16
#           2019-07-03  Scattered showers  SE 10 mph              16
#           2019-07-04      Mostly cloudy   S 25 mph              16
# London    2019-07-01             Shower  SW 16 mph              18
#           2019-07-02         Heavy rain  SW 16 mph              17
#           2019-07-03         Heavy rain  SW 16 mph              19
#           2019-07-04      Mostly cloudy  SW 16 mph              23
# Oxford    2019-07-01             Shower  SW 16 mph              19
#           2019-07-02             Shower  SW 16 mph              19
#           2019-07-03  Scattered showers  SW 16 mph              22
#           2019-07-04             Shower  SW 16 mph              21

# %%
# by default, level=0
# both index and columns default to the level 0

df.drop(index='Oxford')
# Out:
#                                     Day                             \
#                                 Weather       Wind Max Temperature
# City      Date
# Cambridge 2019-07-01             Shower  SW 16 mph              24
#           2019-07-02  Scattered showers   E 20 mph              21
#           2019-07-03  Scattered showers  SE 10 mph              22
#           2019-07-04             Shower   S 25 mph              22
# London    2019-07-01             Shower  SW 16 mph              28
#           2019-07-02             Shower  SW 16 mph              29
#           2019-07-03  Scattered showers  SW 16 mph              29
#           2019-07-04      Mostly cloudy  SW 16 mph              31
#
#                                   Night
#                                 Weather       Wind Max Temperature
# City      Date
# Cambridge 2019-07-01             Shower  SW 16 mph              17
#           2019-07-02  Scattered showers   E 20 mph              16
#           2019-07-03  Scattered showers  SE 10 mph              16
#           2019-07-04      Mostly cloudy   S 25 mph              16
# London    2019-07-01             Shower  SW 16 mph              18
#           2019-07-02         Heavy rain  SW 16 mph              17
#           2019-07-03         Heavy rain  SW 16 mph              19
#           2019-07-04      Mostly cloudy  SW 16 mph              23

# %%
df.drop(columns='Day')
# Out:
#                                   Night
#                                 Weather       Wind Max Temperature
# City      Date
# Cambridge 2019-07-01             Shower  SW 16 mph              17
#           2019-07-02  Scattered showers   E 20 mph              16
#           2019-07-03  Scattered showers  SE 10 mph              16
#           2019-07-04      Mostly cloudy   S 25 mph              16
# London    2019-07-01             Shower  SW 16 mph              18
#           2019-07-02         Heavy rain  SW 16 mph              17
#           2019-07-03         Heavy rain  SW 16 mph              19
#           2019-07-04      Mostly cloudy  SW 16 mph              23
# Oxford    2019-07-01             Shower  SW 16 mph              19
#           2019-07-02             Shower  SW 16 mph              19
#           2019-07-03  Scattered showers  SW 16 mph              22
#           2019-07-04             Shower  SW 16 mph              21

# %%
# Delete a specific index/column combination
# drop the index combination 'Oxford' and '2019-07-04'
df.drop(index=('Oxford', '2019-07-04'))
# Out:
#                                     Day                             \
#                                 Weather       Wind Max Temperature
# City      Date
# Cambridge 2019-07-01             Shower  SW 16 mph              24
#           2019-07-02  Scattered showers   E 20 mph              21
#           2019-07-03  Scattered showers  SE 10 mph              22
#           2019-07-04             Shower   S 25 mph              22
# London    2019-07-01             Shower  SW 16 mph              28
#           2019-07-02             Shower  SW 16 mph              29
#           2019-07-03  Scattered showers  SW 16 mph              29
#           2019-07-04      Mostly cloudy  SW 16 mph              31
# Oxford    2019-07-01             Shower  SW 13 mph              25
#           2019-07-02             Shower  SW 16 mph              26
#           2019-07-03  Scattered showers  SW 16 mph              28
#
#                                   Night
#                                 Weather       Wind Max Temperature
# City      Date
# Cambridge 2019-07-01             Shower  SW 16 mph              17
#           2019-07-02  Scattered showers   E 20 mph              16
#           2019-07-03  Scattered showers  SE 10 mph              16
#           2019-07-04      Mostly cloudy   S 25 mph              16
# London    2019-07-01             Shower  SW 16 mph              18
#           2019-07-02         Heavy rain  SW 16 mph              17
#           2019-07-03         Heavy rain  SW 16 mph              19
#           2019-07-04      Mostly cloudy  SW 16 mph              23
# Oxford    2019-07-01             Shower  SW 16 mph              19
#           2019-07-02             Shower  SW 16 mph              19
#           2019-07-03  Scattered showers  SW 16 mph              22

# %%
# drop the column combination 'Day' and 'Weather'
df.drop(columns=('Day', 'Weather'))
# Out:
#                             Day                              Night             \
#                            Wind Max Temperature            Weather       Wind
# City      Date
# Cambridge 2019-07-01  SW 16 mph              24             Shower  SW 16 mph
#           2019-07-02   E 20 mph              21  Scattered showers   E 20 mph
#           2019-07-03  SE 10 mph              22  Scattered showers  SE 10 mph
#           2019-07-04   S 25 mph              22      Mostly cloudy   S 25 mph
# London    2019-07-01  SW 16 mph              28             Shower  SW 16 mph
#           2019-07-02  SW 16 mph              29         Heavy rain  SW 16 mph
#           2019-07-03  SW 16 mph              29         Heavy rain  SW 16 mph
#           2019-07-04  SW 16 mph              31      Mostly cloudy  SW 16 mph
# Oxford    2019-07-01  SW 13 mph              25             Shower  SW 16 mph
#           2019-07-02  SW 16 mph              26             Shower  SW 16 mph
#           2019-07-03  SW 16 mph              28  Scattered showers  SW 16 mph
#           2019-07-04  SW 14 mph              25             Shower  SW 16 mph
#
#
#                      Max Temperature
# City      Date
# Cambridge 2019-07-01              17
#           2019-07-02              16
#           2019-07-03              16
#           2019-07-04              16
# London    2019-07-01              18
#           2019-07-02              17
#           2019-07-03              19
#           2019-07-04              23
# Oxford    2019-07-01              19
#           2019-07-02              19
#           2019-07-03              22
#           2019-07-04              21

# %%
# specify level to be removed
df.drop(index='2019-07-04', level=1)
# Out:
#                                     Day                             \
#                                 Weather       Wind Max Temperature
# City      Date
# Cambridge 2019-07-01             Shower  SW 16 mph              24
#           2019-07-02  Scattered showers   E 20 mph              21
#           2019-07-03  Scattered showers  SE 10 mph              22
# London    2019-07-01             Shower  SW 16 mph              28
#           2019-07-02             Shower  SW 16 mph              29
#           2019-07-03  Scattered showers  SW 16 mph              29
# Oxford    2019-07-01             Shower  SW 13 mph              25
#           2019-07-02             Shower  SW 16 mph              26
#           2019-07-03  Scattered showers  SW 16 mph              28
#
#                                   Night
#                                 Weather       Wind Max Temperature
# City      Date
# Cambridge 2019-07-01             Shower  SW 16 mph              17
#           2019-07-02  Scattered showers   E 20 mph              16
#           2019-07-03  Scattered showers  SE 10 mph              16
# London    2019-07-01             Shower  SW 16 mph              18
#           2019-07-02         Heavy rain  SW 16 mph              17
#           2019-07-03         Heavy rain  SW 16 mph              19
# Oxford    2019-07-01             Shower  SW 16 mph              19
#           2019-07-02             Shower  SW 16 mph              19
#           2019-07-03  Scattered showers  SW 16 mph              22

# %%
df.drop(columns='Weather', level=1)
# Out:
#                             Day                      Night
#                            Wind Max Temperature       Wind Max Temperature
# City      Date
# Cambridge 2019-07-01  SW 16 mph              24  SW 16 mph              17
#           2019-07-02   E 20 mph              21   E 20 mph              16
#           2019-07-03  SE 10 mph              22  SE 10 mph              16
#           2019-07-04   S 25 mph              22   S 25 mph              16
# London    2019-07-01  SW 16 mph              28  SW 16 mph              18
#           2019-07-02  SW 16 mph              29  SW 16 mph              17
#           2019-07-03  SW 16 mph              29  SW 16 mph              19
#           2019-07-04  SW 16 mph              31  SW 16 mph              23
# Oxford    2019-07-01  SW 13 mph              25  SW 16 mph              19
#           2019-07-02  SW 16 mph              26  SW 16 mph              19
#           2019-07-03  SW 16 mph              28  SW 16 mph              22
#           2019-07-04  SW 14 mph              25  SW 16 mph              21
