# %% [markdown]
# <h1 align='center'> Python_Brewing_API</h1>
#
# - Homebrew is a missing package manager for macOS(or Linux), which provides information of how many times each application has been downloded and store the info in json API.
#
# - To get the information, we need to send a request to two urls: one is for getting package_ame `(https://formulae.brew.sh/api/formula.json)` and description about the app; the other one is to get the analytic data for each app `(https://formulae.brew.sh/api/formula/{package_name}a2ps.json)`.
#
# - To avoid giving burden to the serve, we need to limit the amount of data extraction.
#
# **tips**
#
# - Populate the extracted data into dictionary using key/value pair and then into list
# - Convert the data to json.file using json.dump(data, f, indent=2) for better readability
# - Read the json file using data=json.load(f) then sort the data using data.sort(key=func)
# - Bring in the json data into pandas and convert the column, 'analytic' to list separately then create another dataframe
#     then concatenate the new dataframe with the previous dataframe and do some analysis

# %%
# %load ../command1.py

import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity='all'

pd.options.display.float_format='{:,.2f}'.format
pd.set_option('display.max_colwidth', None)

# %%
import requests
import json
import time

# %%
r=requests.get('https://formulae.brew.sh/api/formula.json')
packages_json=r.json() 

# convert the string to json and extract the first three list of packages to see the structure 
packages_str=json.dumps(packages_json[0:3], indent=4) 
print(packages_str)


# Extract only name of application and the description about that
# Out:
# [
#     {
#         "name": "a2ps",
#         "full_name": "a2ps",
#         "tap": "homebrew/core",
#         "oldname": null,
#         "aliases": [],
#         "versioned_formulae": [],
#         "desc": "Any-to-PostScript filter",
#         "license": "GPL-3.0-or-later",
#         "homepage": "https://www.gnu.org/software/a2ps/",
#         "versions": {
#             "stable": "4.14",
#             "head": null,
#             "bottle": true
#         },
#         "urls": {
#             "stable": {
#                 "url": "https://ftp.gnu.org/gnu/a2ps/a2ps-4.14.tar.gz",
#                 "tag": null,
#                 "revision": null
#             }
#         },
#         "revision": 0,
#         "version_scheme": 0,
#         "bottle": {
#             "stable": {
#                 "rebuild": 4,
#                 "root_url": "https://ghcr.io/v2/homebrew/core",
#                 "files": {
#                     "arm64_monterey": {
#                         "cellar": "/opt/homebrew/Cellar",
#                         "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:b92375f7cc49a7440b431d2248cad0d97c96fcca127dace6efdeb0b2f3faa08c",
#                         "sha256": "b92375f7cc49a7440b431d2248cad0d97c96fcca127dace6efdeb0b2f3faa08c"
#                     },
#                     "arm64_big_sur": {
#                         "cellar": "/opt/homebrew/Cellar",
#                         "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:8ac02041dbec3966b6a695dfc4215b90b9e331ae6eb8c6698cbbfa0175154c9f",
#                         "sha256": "8ac02041dbec3966b6a695dfc4215b90b9e331ae6eb8c6698cbbfa0175154c9f"
#                     },
#                     "monterey": {
#                         "cellar": "/usr/local/Cellar",
#                         "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:c0347849efe7486dfa2c5cfd35fae4c87e194fdcd9a10c6ce8758c99e8cf144c",
#                         "sha256": "c0347849efe7486dfa2c5cfd35fae4c87e194fdcd9a10c6ce8758c99e8cf144c"
#                     },
#                     "big_sur": {
#                         "cellar": "/usr/local/Cellar",
#                         "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:e87da2b47386fc7e3c6f20b3ff90c4bbe37b9e0aaa884440ffa216492dbc150b",
#                         "sha256": "e87da2b47386fc7e3c6f20b3ff90c4bbe37b9e0aaa884440ffa216492dbc150b"
#                     },
#                     "catalina": {
#                         "cellar": "/usr/local/Cellar",
#                         "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:82e64b2008971430d160a3f564e32593e98fb55c43d7748c7deb9d6f546e1102",
#                         "sha256": "82e64b2008971430d160a3f564e32593e98fb55c43d7748c7deb9d6f546e1102"
#                     },
#                     "mojave": {
#                         "cellar": "/usr/local/Cellar",
#                         "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:8ca49b4797277f79e87e48ab4c6794601b64d1dde35b9eac556d4153b8237a51",
#                         "sha256": "8ca49b4797277f79e87e48ab4c6794601b64d1dde35b9eac556d4153b8237a51"
#                     },
#                     "x86_64_linux": {
#                         "cellar": "/home/linuxbrew/.linuxbrew/Cellar",
#                         "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:063b4b31a62c4d5bd905bc4faab09ac2a50c77291de52ab216fc6a7a56f8e406",
#                         "sha256": "063b4b31a62c4d5bd905bc4faab09ac2a50c77291de52ab216fc6a7a56f8e406"
#                     }
#                 }
#             }
#         },
#         "keg_only": false,
#         "keg_only_reason": null,
#         "options": [],
#         "build_dependencies": [],
#         "dependencies": [],
#         "recommended_dependencies": [],
#         "optional_dependencies": [],
#         "uses_from_macos": [
#             "gperf"
#         ],
#         "requirements": [],
#         "conflicts_with": [],
#         "caveats": null,
#         "installed": [],
#         "linked_keg": null,
#         "pinned": false,
#         "outdated": false,
#         "deprecated": false,
#         "deprecation_date": null,
#         "deprecation_reason": null,
#         "disabled": false,
#         "disable_date": null,
#         "disable_reason": null
#     },
#     {
#         "name": "a52dec",
#         "full_name": "a52dec",
#         "tap": "homebrew/core",
#         "oldname": null,
#         "aliases": [],
#         "versioned_formulae": [],
#         "desc": "Library for decoding ATSC A/52 streams (AKA 'AC-3')",
#         "license": "GPL-2.0-or-later",
#         "homepage": "https://liba52.sourceforge.io/",
#         "versions": {
#             "stable": "0.7.4",
#             "head": null,
#             "bottle": true
#         },
#         "urls": {
#             "stable": {
#                 "url": "https://liba52.sourceforge.io/files/a52dec-0.7.4.tar.gz",
#                 "tag": null,
#                 "revision": null
#             }
#         },
#         "revision": 0,
#         "version_scheme": 0,
#         "bottle": {
#             "stable": {
#                 "rebuild": 1,
#                 "root_url": "https://ghcr.io/v2/homebrew/core",
#                 "files": {
#                     "arm64_monterey": {
#                         "cellar": ":any_skip_relocation",
#                         "url": "https://ghcr.io/v2/homebrew/core/a52dec/blobs/sha256:8f17299eecdcf8d9a94bff90a2f48e9c2a2cffdee3b64d2633865d983171be17",
#                         "sha256": "8f17299eecdcf8d9a94bff90a2f48e9c2a2cffdee3b64d2633865d983171be17"
#                     },
#                     "arm64_big_sur": {
#                         "cellar": ":any",
#                         "url": "https://ghcr.io/v2/homebrew/core/a52dec/blobs/sha256:a9a4752a7b6d4872abf06a725a44b94d1701e4621c0e4226002e371df53ff366",
#                         "sha256": "a9a4752a7b6d4872abf06a725a44b94d1701e4621c0e4226002e371df53ff366"
#                     },
#                     "monterey": {
#                         "cellar": ":any_skip_relocation",
#                         "url": "https://ghcr.io/v2/homebrew/core/a52dec/blobs/sha256:5861dcdb362d4993facf91724306204fc4775c62ab91dd340144b73897a14043",
#                         "sha256": "5861dcdb362d4993facf91724306204fc4775c62ab91dd340144b73897a14043"
#                     },
#                     "big_sur": {
#                         "cellar": ":any",
#                         "url": "https://ghcr.io/v2/homebrew/core/a52dec/blobs/sha256:f5b95a6c1f7758e29cc04160d3635fce074c6c527cb3ac209877d8e4d1b4935c",
#                         "sha256": "f5b95a6c1f7758e29cc04160d3635fce074c6c527cb3ac209877d8e4d1b4935c"
#                     },
#                     "catalina": {
#                         "cellar": ":any",
#                         "url": "https://ghcr.io/v2/homebrew/core/a52dec/blobs/sha256:949600b627a44697bc12713538c5aed594fc8201694f5c453c8ca5f9f8cd335a",
#                         "sha256": "949600b627a44697bc12713538c5aed594fc8201694f5c453c8ca5f9f8cd335a"
#                     },
#                     "mojave": {
#                         "cellar": ":any",
#                         "url": "https://ghcr.io/v2/homebrew/core/a52dec/blobs/sha256:a47f3248a481d224edcbec3e266793ff73f2e94bb607732df2166a0c6f442596",
#                         "sha256": "a47f3248a481d224edcbec3e266793ff73f2e94bb607732df2166a0c6f442596"
#                     },
#                     "x86_64_linux": {
#                         "cellar": ":any_skip_relocation",
#                         "url": "https://ghcr.io/v2/homebrew/core/a52dec/blobs/sha256:6ba162f41f0366039355b26d363506794d39f75cbb48d8ba5879337f6c5394eb",
#                         "sha256": "6ba162f41f0366039355b26d363506794d39f75cbb48d8ba5879337f6c5394eb"
#                     }
#                 }
#             }
#         },
#         "keg_only": false,
#         "keg_only_reason": null,
#         "options": [],
#         "build_dependencies": [],
#         "dependencies": [],
#         "recommended_dependencies": [],
#         "optional_dependencies": [],
#         "uses_from_macos": [],
#         "requirements": [],
#         "conflicts_with": [],
#         "caveats": null,
#         "installed": [],
#         "linked_keg": null,
#         "pinned": false,
#         "outdated": false,
#         "deprecated": false,
#         "deprecation_date": null,
#         "deprecation_reason": null,
#         "disabled": false,
#         "disable_date": null,
#         "disable_reason": null
#     },
#     {
#         "name": "aacgain",
#         "full_name": "aacgain",
#         "tap": "homebrew/core",
#         "oldname": null,
#         "aliases": [],
#         "versioned_formulae": [],
#         "desc": "AAC-supporting version of mp3gain",
#         "license": "GPL-2.0-or-later",
#         "homepage": "https://aacgain.altosdesign.com/",
#         "versions": {
#             "stable": "1.8",
#             "head": null,
#             "bottle": true
#         },
#         "urls": {
#             "stable": {
#                 "url": "https://aacgain.altosdesign.com/alvarez/aacgain-1.8.tar.bz2",
#                 "tag": null,
#                 "revision": null
#             }
#         },
#         "revision": 0,
#         "version_scheme": 0,
#         "bottle": {
#             "stable": {
#                 "rebuild": 0,
#                 "root_url": "https://ghcr.io/v2/homebrew/core",
#                 "files": {
#                     "arm64_monterey": {
#                         "cellar": ":any_skip_relocation",
#                         "url": "https://ghcr.io/v2/homebrew/core/aacgain/blobs/sha256:4c8bc457323db05d4c0ccd01187cc74d4367d5704953ced03883e7a806715b05",
#                         "sha256": "4c8bc457323db05d4c0ccd01187cc74d4367d5704953ced03883e7a806715b05"
#                     },
#                     "arm64_big_sur": {
#                         "cellar": ":any_skip_relocation",
#                         "url": "https://ghcr.io/v2/homebrew/core/aacgain/blobs/sha256:5d09e7e41cb2fa9ab670f19797812669151b4b74c308ced6f00dfa8cfc83de0c",
#                         "sha256": "5d09e7e41cb2fa9ab670f19797812669151b4b74c308ced6f00dfa8cfc83de0c"
#                     },
#                     "monterey": {
#                         "cellar": ":any_skip_relocation",
#                         "url": "https://ghcr.io/v2/homebrew/core/aacgain/blobs/sha256:d057764a1d3416927fa973ac5d883f0a790a5f5fc425f39e1577bfae2513a2a3",
#                         "sha256": "d057764a1d3416927fa973ac5d883f0a790a5f5fc425f39e1577bfae2513a2a3"
#                     },
#                     "big_sur": {
#                         "cellar": ":any_skip_relocation",
#                         "url": "https://ghcr.io/v2/homebrew/core/aacgain/blobs/sha256:f2adb8395d6c19e95733f54bf0665cca7f405f9d4489544d69d86704da3d545c",
#                         "sha256": "f2adb8395d6c19e95733f54bf0665cca7f405f9d4489544d69d86704da3d545c"
#                     },
#                     "catalina": {
#                         "cellar": ":any_skip_relocation",
#                         "url": "https://ghcr.io/v2/homebrew/core/aacgain/blobs/sha256:a8ec07d22279b4bdd471ee7a307e6d365a906432ef49533afeca2de53add8d55",
#                         "sha256": "a8ec07d22279b4bdd471ee7a307e6d365a906432ef49533afeca2de53add8d55"
#                     },
#                     "mojave": {
#                         "cellar": ":any_skip_relocation",
#                         "url": "https://ghcr.io/v2/homebrew/core/aacgain/blobs/sha256:a6d9e4d4f20311e0a91bdbc6f42ef8894e6a6b9f4d8290938d14f02868821c0d",
#                         "sha256": "a6d9e4d4f20311e0a91bdbc6f42ef8894e6a6b9f4d8290938d14f02868821c0d"
#                     },
#                     "high_sierra": {
#                         "cellar": ":any_skip_relocation",
#                         "url": "https://ghcr.io/v2/homebrew/core/aacgain/blobs/sha256:eda9c36cf9517c9f342031632b9fb38f77d8150cc2a7cf88b57e46f77395c96e",
#                         "sha256": "eda9c36cf9517c9f342031632b9fb38f77d8150cc2a7cf88b57e46f77395c96e"
#                     },
#                     "sierra": {
#                         "cellar": ":any_skip_relocation",
#                         "url": "https://ghcr.io/v2/homebrew/core/aacgain/blobs/sha256:2d7ea587b06feb7ccb4f6dfaee3a6d7b329e041cc80af969afb8b5d1631997e8",
#                         "sha256": "2d7ea587b06feb7ccb4f6dfaee3a6d7b329e041cc80af969afb8b5d1631997e8"
#                     },
#                     "el_capitan": {
#                         "cellar": ":any_skip_relocation",
#                         "url": "https://ghcr.io/v2/homebrew/core/aacgain/blobs/sha256:b97aaaf19fee69734b4a29e22c498becaa94b3025a192a7ef8f1ecfb0a2ce87c",
#                         "sha256": "b97aaaf19fee69734b4a29e22c498becaa94b3025a192a7ef8f1ecfb0a2ce87c"
#                     }
#                 }
#             }
#         },
#         "keg_only": false,
#         "keg_only_reason": null,
#         "options": [],
#         "build_dependencies": [],
#         "dependencies": [],
#         "recommended_dependencies": [],
#         "optional_dependencies": [],
#         "uses_from_macos": [],
#         "requirements": [],
#         "conflicts_with": [],
#         "caveats": null,
#         "installed": [],
#         "linked_keg": null,
#         "pinned": false,
#         "outdated": false,
#         "deprecated": false,
#         "deprecation_date": null,
#         "deprecation_reason": null,
#         "disabled": false,
#         "disable_date": null,
#         "disable_reason": null
#     }
# ]

# %%
for package in packages_json:
    package_name=package['name']
    package_desc=package['desc']
    package_url=f'https://formulae.brew.sh/api/formula/{package_name}.json'
    r=requests.get(package_url)
    package_json=r.json() 
    json_str=json.dumps(package_json, indent=4)
    print(json_str)
    break
# Out:
# {
#     "name": "a2ps",
#     "full_name": "a2ps",
#     "tap": "homebrew/core",
#     "oldname": null,
#     "aliases": [],
#     "versioned_formulae": [],
#     "desc": "Any-to-PostScript filter",
#     "license": "GPL-3.0-or-later",
#     "homepage": "https://www.gnu.org/software/a2ps/",
#     "versions": {
#         "stable": "4.14",
#         "head": null,
#         "bottle": true
#     },
#     "urls": {
#         "stable": {
#             "url": "https://ftp.gnu.org/gnu/a2ps/a2ps-4.14.tar.gz",
#             "tag": null,
#             "revision": null
#         }
#     },
#     "revision": 0,
#     "version_scheme": 0,
#     "bottle": {
#         "stable": {
#             "rebuild": 4,
#             "root_url": "https://ghcr.io/v2/homebrew/core",
#             "files": {
#                 "arm64_monterey": {
#                     "cellar": "/opt/homebrew/Cellar",
#                     "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:b92375f7cc49a7440b431d2248cad0d97c96fcca127dace6efdeb0b2f3faa08c",
#                     "sha256": "b92375f7cc49a7440b431d2248cad0d97c96fcca127dace6efdeb0b2f3faa08c"
#                 },
#                 "arm64_big_sur": {
#                     "cellar": "/opt/homebrew/Cellar",
#                     "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:8ac02041dbec3966b6a695dfc4215b90b9e331ae6eb8c6698cbbfa0175154c9f",
#                     "sha256": "8ac02041dbec3966b6a695dfc4215b90b9e331ae6eb8c6698cbbfa0175154c9f"
#                 },
#                 "monterey": {
#                     "cellar": "/usr/local/Cellar",
#                     "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:c0347849efe7486dfa2c5cfd35fae4c87e194fdcd9a10c6ce8758c99e8cf144c",
#                     "sha256": "c0347849efe7486dfa2c5cfd35fae4c87e194fdcd9a10c6ce8758c99e8cf144c"
#                 },
#                 "big_sur": {
#                     "cellar": "/usr/local/Cellar",
#                     "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:e87da2b47386fc7e3c6f20b3ff90c4bbe37b9e0aaa884440ffa216492dbc150b",
#                     "sha256": "e87da2b47386fc7e3c6f20b3ff90c4bbe37b9e0aaa884440ffa216492dbc150b"
#                 },
#                 "catalina": {
#                     "cellar": "/usr/local/Cellar",
#                     "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:82e64b2008971430d160a3f564e32593e98fb55c43d7748c7deb9d6f546e1102",
#                     "sha256": "82e64b2008971430d160a3f564e32593e98fb55c43d7748c7deb9d6f546e1102"
#                 },
#                 "mojave": {
#                     "cellar": "/usr/local/Cellar",
#                     "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:8ca49b4797277f79e87e48ab4c6794601b64d1dde35b9eac556d4153b8237a51",
#                     "sha256": "8ca49b4797277f79e87e48ab4c6794601b64d1dde35b9eac556d4153b8237a51"
#                 },
#                 "x86_64_linux": {
#                     "cellar": "/home/linuxbrew/.linuxbrew/Cellar",
#                     "url": "https://ghcr.io/v2/homebrew/core/a2ps/blobs/sha256:063b4b31a62c4d5bd905bc4faab09ac2a50c77291de52ab216fc6a7a56f8e406",
#                     "sha256": "063b4b31a62c4d5bd905bc4faab09ac2a50c77291de52ab216fc6a7a56f8e406"
#                 }
#             }
#         }
#     },
#     "keg_only": false,
#     "keg_only_reason": null,
#     "options": [],
#     "build_dependencies": [],
#     "dependencies": [],
#     "recommended_dependencies": [],
#     "optional_dependencies": [],
#     "uses_from_macos": [
#         "gperf"
#     ],
#     "requirements": [],
#     "conflicts_with": [],
#     "caveats": null,
#     "installed": [],
#     "linked_keg": null,
#     "pinned": false,
#     "outdated": false,
#     "deprecated": false,
#     "deprecation_date": null,
#     "deprecation_reason": null,
#     "disabled": false,
#     "disable_date": null,
#     "disable_reason": null,
#     "analytics": {
#         "install": {
#             "30d": {
#                 "a2ps": 110
#             },
#             "90d": {
#                 "a2ps": 321
#             },
#             "365d": {
#                 "a2ps": 1304
#             }
#         },
#         "install_on_request": {
#             "30d": {
#                 "a2ps": 110
#             },
#             "90d": {
#                 "a2ps": 320
#             },
#             "365d": {
#                 "a2ps": 1304
#             }
#         },
#         "build_error": {
#             "30d": {
#                 "a2ps": 1
#             }
#         }
#     },
#     "analytics-linux": {
#         "install": {
#             "30d": {
#                 "a2ps": 2
#             },
#             "90d": {
#                 "a2ps": 5
#             },
#             "365d": {
#                 "a2ps": 21
#             }
#         },
#         "install_on_request": {
#             "30d": {
#                 "a2ps": 2
#             },
#             "90d": {
#                 "a2ps": 5
#             },
#             "365d": {
#                 "a2ps": 21
#             }
#         },
#         "build_error": {
#             "30d": {
#                 "a2ps": 0
#             }
#         }
#     },
#     "generated_date": "2022-07-09"
# }

# %%
results=[]
for package in packages_json:
    package_name=package['name']
    package_desc=package['desc']
    package_url=f'https://formulae.brew.sh/api/formula/{package_name}.json'
    r=requests.get(package_url)
    package_json=r.json() # json_str
    
    install_30d=package_json['analytics']['install_on_request']['30d'][package_name]
    install_90d=package_json['analytics']['install_on_request']['90d'][package_name]
    install_365d=package_json['analytics']['install_on_request']['365d'][package_name]
    
    data={'name': package_name,
         'desc':package_desc,
         'analytic':{'30d':install_30d,
                    '90d':install_90d,
                    '365d':install_365d}}
    results.append(data)
    break

print(results)
# Out:
# [{'name': 'a2ps', 'desc': 'Any-to-PostScript filter', 'analytic': {'30d': 110, '90d': 320, '365d': 1304}}]

# %%
results=[]

t1=time.perf_counter()

# retreiving the whole info takes more than 10 min and give some burden server os we just retieve only the first ten items
for package in packages_json[:10]:  
    package_name=package['name']
    package_desc=package['desc']
    package_url=f'https://formulae.brew.sh/api/formula/{package_name}.json'
    r=requests.get(package_url)
    package_json=r.json() # json_str
    
  

    install_30d=package_json['analytics']['install_on_request']['30d'][package_name]
    install_90d=package_json['analytics']['install_on_request']['90d'][package_name]
    install_365d=package_json['analytics']['install_on_request']['365d'][package_name]

    data={'name': package_name,
         'desc':package_desc,
         'analytic':{'30d':install_30d,
                    '90d':install_90d,
                    '365d':install_365d}}
    results.append(data)
    
    time.sleep(r.elapsed.total_seconds())
    print(f'Got {package_name} in {r.elapsed.total_seconds()} seconds')
    
    
    
t2=time.perf_counter()
print(f'Finished in {t2-t1} seconds')

with open('package_info.json', 'w') as f:
    json.dump(results, f, indent=2)
# Out:
# Got a2ps in 0.094825 seconds
# Got a52dec in 0.407229 seconds
# Got aacgain in 0.208594 seconds
# Got aalib in 0.220442 seconds
# Got aamath in 0.209638 seconds
# Got aarch64-elf-binutils in 0.211691 seconds
# Got aarch64-elf-gcc in 0.20662 seconds
# Got aardvark_shell_utils in 0.224229 seconds
# Got abcde in 0.204381 seconds
# Got abcl in 0.207387 seconds
# Finished in 4.5924874 seconds

# %%
with open('package_info.json', 'r') as f:
    data=json.load(f)

print(json.dumps(data[:3], indent=2))
print('\n\n')

data.sort(key=lambda package:package['analytic']['30d'], reverse=True)

print(json.dumps(data[:3], indent=2))
# Out:
# [
#   {
#     "name": "a2ps",
#     "desc": "Any-to-PostScript filter",
#     "analytic": {
#       "30d": 110,
#       "90d": 320,
#       "365d": 1304
#     }
#   },
#   {
#     "name": "a52dec",
#     "desc": "Library for decoding ATSC A/52 streams (AKA 'AC-3')",
#     "analytic": {
#       "30d": 26,
#       "90d": 82,
#       "365d": 348
#     }
#   },
#   {
#     "name": "aacgain",
#     "desc": "AAC-supporting version of mp3gain",
#     "analytic": {
#       "30d": 44,
#       "90d": 169,
#       "365d": 683
#     }
#   }
# ]
#
#
#
# [
#   {
#     "name": "a2ps",
#     "desc": "Any-to-PostScript filter",
#     "analytic": {
#       "30d": 110,
#       "90d": 320,
#       "365d": 1304
#     }
#   },
#   {
#     "name": "aalib",
#     "desc": "Portable ASCII art graphics library",
#     "analytic": {
#       "30d": 108,
#       "90d": 261,
#       "365d": 1290
#     }
#   },
#   {
#     "name": "aarch64-elf-gcc",
#     "desc": "GNU compiler collection for aarch64-elf",
#     "analytic": {
#       "30d": 84,
#       "90d": 286,
#       "365d": 397
#     }
#   }
# ]

# %%
data1=[item for item in data if 'graphics' in item['desc']]
print(json.dumps(data1, indent=2))
# Out:
# [
#   {
#     "name": "aalib",
#     "desc": "Portable ASCII art graphics library",
#     "analytic": {
#       "30d": 108,
#       "90d": 261,
#       "365d": 1290
#     }
#   }
# ]

# %%
import pandas as pd

# %%
df=pd.read_json('package_info.json')
df
# Out:
#                    name  \
# 0                  a2ps
# 1                a52dec
# 2               aacgain
# 3                 aalib
# 4                aamath
# 5  aarch64-elf-binutils
# 6       aarch64-elf-gcc
# 7  aardvark_shell_utils
# 8                 abcde
# 9                  abcl
#
#                                                            desc  \
# 0                                      Any-to-PostScript filter
# 1           Library for decoding ATSC A/52 streams (AKA 'AC-3')
# 2                             AAC-supporting version of mp3gain
# 3                           Portable ASCII art graphics library
# 4                 Renders mathematical expressions as ASCII art
# 5                GNU Binutils for aarch64-elf cross development
# 6                       GNU compiler collection for aarch64-elf
# 7          Utilities to aid shell scripts or command-line users
# 8                                             Better CD Encoder
# 9  Armed Bear Common Lisp: a full implementation of Common Lisp
#
#                                  analytic
# 0  {'30d': 110, '90d': 320, '365d': 1304}
# 1     {'30d': 26, '90d': 82, '365d': 348}
# 2    {'30d': 44, '90d': 169, '365d': 683}
# 3  {'30d': 108, '90d': 261, '365d': 1290}
# 4     {'30d': 10, '90d': 30, '365d': 266}
# 5    {'30d': 33, '90d': 102, '365d': 175}
# 6    {'30d': 84, '90d': 286, '365d': 397}
# 7     {'30d': 11, '90d': 47, '365d': 185}
# 8    {'30d': 30, '90d': 127, '365d': 637}
# 9    {'30d': 21, '90d': 131, '365d': 317}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     object
#  1   desc      10 non-null     object
#  2   analytic  10 non-null     object
# dtypes: object(3)
# memory usage: 368.0+ bytes

# %%
print(type(df.loc[0, 'analytic']))
# Out:
# <class 'dict'>

# %%
anal_info=df['analytic']

anal_info

anal_info_list=anal_info.to_list()

anal_info_list
# Out:
# 0    {'30d': 110, '90d': 320, '365d': 1304}
# 1       {'30d': 26, '90d': 82, '365d': 348}
# 2      {'30d': 44, '90d': 169, '365d': 683}
# 3    {'30d': 108, '90d': 261, '365d': 1290}
# 4       {'30d': 10, '90d': 30, '365d': 266}
# 5      {'30d': 33, '90d': 102, '365d': 175}
# 6      {'30d': 84, '90d': 286, '365d': 397}
# 7       {'30d': 11, '90d': 47, '365d': 185}
# 8      {'30d': 30, '90d': 127, '365d': 637}
# 9      {'30d': 21, '90d': 131, '365d': 317}
# Name: analytic, dtype: object
# [{'30d': 110, '90d': 320, '365d': 1304},
#  {'30d': 26, '90d': 82, '365d': 348},
#  {'30d': 44, '90d': 169, '365d': 683},
#  {'30d': 108, '90d': 261, '365d': 1290},
#  {'30d': 10, '90d': 30, '365d': 266},
#  {'30d': 33, '90d': 102, '365d': 175},
#  {'30d': 84, '90d': 286, '365d': 397},
#  {'30d': 11, '90d': 47, '365d': 185},
#  {'30d': 30, '90d': 127, '365d': 637},
#  {'30d': 21, '90d': 131, '365d': 317}]

# %%
anal_info_df=pd.DataFrame(anal_info_list)

anal_info_df
# Out:
#    30d  90d  365d
# 0  110  320  1304
# 1   26   82   348
# 2   44  169   683
# 3  108  261  1290
# 4   10   30   266
# 5   33  102   175
# 6   84  286   397
# 7   11   47   185
# 8   30  127   637
# 9   21  131   317

# %%
combined_df=pd.concat([df, anal_info_df], ignore_index=True, axis='columns')

combined_df
# Out:
#                       0  \
# 0                  a2ps
# 1                a52dec
# 2               aacgain
# 3                 aalib
# 4                aamath
# 5  aarch64-elf-binutils
# 6       aarch64-elf-gcc
# 7  aardvark_shell_utils
# 8                 abcde
# 9                  abcl
#
#                                                               1  \
# 0                                      Any-to-PostScript filter
# 1           Library for decoding ATSC A/52 streams (AKA 'AC-3')
# 2                             AAC-supporting version of mp3gain
# 3                           Portable ASCII art graphics library
# 4                 Renders mathematical expressions as ASCII art
# 5                GNU Binutils for aarch64-elf cross development
# 6                       GNU compiler collection for aarch64-elf
# 7          Utilities to aid shell scripts or command-line users
# 8                                             Better CD Encoder
# 9  Armed Bear Common Lisp: a full implementation of Common Lisp
#
#                                         2    3    4     5
# 0  {'30d': 110, '90d': 320, '365d': 1304}  110  320  1304
# 1     {'30d': 26, '90d': 82, '365d': 348}   26   82   348
# 2    {'30d': 44, '90d': 169, '365d': 683}   44  169   683
# 3  {'30d': 108, '90d': 261, '365d': 1290}  108  261  1290
# 4     {'30d': 10, '90d': 30, '365d': 266}   10   30   266
# 5    {'30d': 33, '90d': 102, '365d': 175}   33  102   175
# 6    {'30d': 84, '90d': 286, '365d': 397}   84  286   397
# 7     {'30d': 11, '90d': 47, '365d': 185}   11   47   185
# 8    {'30d': 30, '90d': 127, '365d': 637}   30  127   637
# 9    {'30d': 21, '90d': 131, '365d': 317}   21  131   317

# %%
combined_df.columns

combined_df.drop(2, axis='columns', inplace=True)

combined_df
# Out:
# RangeIndex(start=0, stop=6, step=1)
#                       0  \
# 0                  a2ps
# 1                a52dec
# 2               aacgain
# 3                 aalib
# 4                aamath
# 5  aarch64-elf-binutils
# 6       aarch64-elf-gcc
# 7  aardvark_shell_utils
# 8                 abcde
# 9                  abcl
#
#                                                               1    3    4  \
# 0                                      Any-to-PostScript filter  110  320
# 1           Library for decoding ATSC A/52 streams (AKA 'AC-3')   26   82
# 2                             AAC-supporting version of mp3gain   44  169
# 3                           Portable ASCII art graphics library  108  261
# 4                 Renders mathematical expressions as ASCII art   10   30
# 5                GNU Binutils for aarch64-elf cross development   33  102
# 6                       GNU compiler collection for aarch64-elf   84  286
# 7          Utilities to aid shell scripts or command-line users   11   47
# 8                                             Better CD Encoder   30  127
# 9  Armed Bear Common Lisp: a full implementation of Common Lisp   21  131
#
#       5
# 0  1304
# 1   348
# 2   683
# 3  1290
# 4   266
# 5   175
# 6   397
# 7   185
# 8   637
# 9   317

# %%
combined_df.rename(columns={0:'Name', 1:'Desc', 3:'30d', 4:'90d', 5:'365d'}, inplace=True)


combined_df
# Out:
#                    Name  \
# 0                  a2ps
# 1                a52dec
# 2               aacgain
# 3                 aalib
# 4                aamath
# 5  aarch64-elf-binutils
# 6       aarch64-elf-gcc
# 7  aardvark_shell_utils
# 8                 abcde
# 9                  abcl
#
#                                                            Desc  30d  90d  \
# 0                                      Any-to-PostScript filter  110  320
# 1           Library for decoding ATSC A/52 streams (AKA 'AC-3')   26   82
# 2                             AAC-supporting version of mp3gain   44  169
# 3                           Portable ASCII art graphics library  108  261
# 4                 Renders mathematical expressions as ASCII art   10   30
# 5                GNU Binutils for aarch64-elf cross development   33  102
# 6                       GNU compiler collection for aarch64-elf   84  286
# 7          Utilities to aid shell scripts or command-line users   11   47
# 8                                             Better CD Encoder   30  127
# 9  Armed Bear Common Lisp: a full implementation of Common Lisp   21  131
#
#    365d
# 0  1304
# 1   348
# 2   683
# 3  1290
# 4   266
# 5   175
# 6   397
# 7   185
# 8   637
# 9   317

# %%
df_final=combined_df

df_final
# Out:
#                    Name  \
# 0                  a2ps
# 1                a52dec
# 2               aacgain
# 3                 aalib
# 4                aamath
# 5  aarch64-elf-binutils
# 6       aarch64-elf-gcc
# 7  aardvark_shell_utils
# 8                 abcde
# 9                  abcl
#
#                                                            Desc  30d  90d  \
# 0                                      Any-to-PostScript filter  110  320
# 1           Library for decoding ATSC A/52 streams (AKA 'AC-3')   26   82
# 2                             AAC-supporting version of mp3gain   44  169
# 3                           Portable ASCII art graphics library  108  261
# 4                 Renders mathematical expressions as ASCII art   10   30
# 5                GNU Binutils for aarch64-elf cross development   33  102
# 6                       GNU compiler collection for aarch64-elf   84  286
# 7          Utilities to aid shell scripts or command-line users   11   47
# 8                                             Better CD Encoder   30  127
# 9  Armed Bear Common Lisp: a full implementation of Common Lisp   21  131
#
#    365d
# 0  1304
# 1   348
# 2   683
# 3  1290
# 4   266
# 5   175
# 6   397
# 7   185
# 8   637
# 9   317

# %%
df_final.sort_values(by='30d', ascending=False)
# Out:
#                    Name  \
# 0                  a2ps
# 3                 aalib
# 6       aarch64-elf-gcc
# 2               aacgain
# 5  aarch64-elf-binutils
# 8                 abcde
# 1                a52dec
# 9                  abcl
# 7  aardvark_shell_utils
# 4                aamath
#
#                                                            Desc  30d  90d  \
# 0                                      Any-to-PostScript filter  110  320
# 3                           Portable ASCII art graphics library  108  261
# 6                       GNU compiler collection for aarch64-elf   84  286
# 2                             AAC-supporting version of mp3gain   44  169
# 5                GNU Binutils for aarch64-elf cross development   33  102
# 8                                             Better CD Encoder   30  127
# 1           Library for decoding ATSC A/52 streams (AKA 'AC-3')   26   82
# 9  Armed Bear Common Lisp: a full implementation of Common Lisp   21  131
# 7          Utilities to aid shell scripts or command-line users   11   47
# 4                 Renders mathematical expressions as ASCII art   10   30
#
#    365d
# 0  1304
# 3  1290
# 6   397
# 2   683
# 5   175
# 8   637
# 1   348
# 9   317
# 7   185
# 4   266

# %%
filt=df_final['Desc'].str.contains('mp3')

df_final.loc[filt]
# Out:
#       Name                               Desc  30d  90d  365d
# 2  aacgain  AAC-supporting version of mp3gain   44  169   683
