# %% [markdown]
# <h1>geopandas-working-with-attributes </h1>

# %% [markdown]
# - The goal of this small project is that we download the population data and mark the places where its population is gerater than 1 million onto the map and save the resultant data as GeoJSON file.
#
#
# - The data source is <a href='https://www.qgistutorials.com/en/docs/3/working_with_attributes.html'> Working with Attributes (QGIS3) </a>
# - Here, we are going to use GeoPandas, not QGIS3
# - Geographic Information System (GIS) has two parts: features and attributes.
#     - Attributes are structured data about each feature
#
#
#
# - Data
#     - Populated Places <a href='http://www.naturalearthdata.com/downloads/10m-cultural-vectors/10m-populated-places/'> here </a> : Please download this "ne_10m_populated_places_simple.zip"

# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from urllib import request
# %matplotlib inline

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity='all'

# %config InlineBackend.figure_format='svg'
plt.rcParams['figure.dpi']=120

pd.options.display.float_format='{:,.2f}'.format
pd.set_option('display.max_colwidth', None)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
url = "https://www.qgistutorials.com/downloads/ne_10m_populated_places_simple.zip"
fname = 'population_places.zip'
request.urlretrieve(url, fname)
# Out:
# ('population_places.zip', <http.client.HTTPMessage at 0x27253324e20>)

# %%
from zipfile import ZipFile

file_name = "population_places.zip"

with ZipFile(file_name, 'r') as zip:
    # zip.printdir()
    zip.extractall()

# %%
import os

os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  'from_github',
#  'geopandas_working_with_attributes.ipynb',
#  'ne_10m_populated_places_simple.cpg',
#  'ne_10m_populated_places_simple.dbf',
#  'ne_10m_populated_places_simple.prj',
#  'ne_10m_populated_places_simple.README.html',
#  'ne_10m_populated_places_simple.shp',
#  'ne_10m_populated_places_simple.shx',
#  'ne_10m_populated_places_simple.VERSION.txt',
#  'populated_capitals.geojson',
#  'population_places.zip']

# %% [markdown]
# **Create geopandas dataframe**

# %%
fname = 'ne_10m_populated_places_simple.shp'
gdf = gpd.read_file(fname)

# %%
gdf.head(3)
# Out:
#    scalerank  natscale  labelrank       featurecla                    name  \
# 0         10         1          8  Admin-1 capital  Colonia del Sacramento
# 1         10         1          8  Admin-1 capital                Trinidad
# 2         10         1          8  Admin-1 capital             Fray Bentos
#
#   namepar namealt  diffascii               nameascii  adm0cap  ...  rank_max  \
# 0    None    None          0  Colonia del Sacramento     0.00  ...         7
# 1    None    None          0                Trinidad     0.00  ...         7
# 2    None    None          0             Fray Bentos     0.00  ...         7
#
#   rank_min    geonameid  meganame ls_name ls_match checkme min_zoom  \
# 0        7 3,443,013.00      None    None        0       0     9.00
# 1        7 3,439,749.00      None    None        0       0     9.00
# 2        7 3,442,568.00      None    None        0       0     9.00
#
#         ne_id                     geometry
# 0  1159112629  POINT (-57.84000 -34.48000)
# 1  1159112647  POINT (-56.90100 -33.54400)
# 2  1159112663  POINT (-58.30400 -33.13900)
#
# [3 rows x 39 columns]

# %%
gdf['adm0cap'].unique() # when the country has country capita data then it is marked as 1 otherwise it is 0
# Out:
# array([0., 1.])

# %%
gdf.columns
# Out:
# Index(['scalerank', 'natscale', 'labelrank', 'featurecla', 'name', 'namepar',
#        'namealt', 'diffascii', 'nameascii', 'adm0cap', 'capalt', 'capin',
#        'worldcity', 'megacity', 'sov0name', 'sov_a3', 'adm0name', 'adm0_a3',
#        'adm1name', 'iso_a2', 'note', 'latitude', 'longitude', 'changed',
#        'namediff', 'diffnote', 'pop_max', 'pop_min', 'pop_other', 'rank_max',
#        'rank_min', 'geonameid', 'meganame', 'ls_name', 'ls_match', 'checkme',
#        'min_zoom', 'ne_id', 'geometry'],
#       dtype='object')

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# **explore() method allows your map to be interactive map**

# %% [markdown]
# - The basemap can be found in a website ("leaflet Provide Demo")
#
# - Or we can get the basemaps from Hatarilab ("https://hatarilabs.com/ih-en/how-to-add-a-google-map-in-qgis-3-tutorial"

# %%
gdf.head(100).explore(tiles='http://mt0.google.com/vt/lyrs=y&hl=en&x={x}&y={y}&z={z}',
                      attr='Google Satellite', marker_kwds={'radius':10},
                     style_kwds={'fillColor':'red'}, popup=['name','adm0cap','pop_max'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ece55ddfa0bf4ea0fb7ddb2df672e5c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ece55ddfa0bf4ea0fb7ddb2df672e5c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ece55ddfa0bf4ea0fb7ddb2df672e5c2 = L.map(
#                 &quot;map_ece55ddfa0bf4ea0fb7ddb2df672e5c2&quot;,
#                 {
#                     center: [6.783498036387243, 10.06700006815305],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ece55ddfa0bf4ea0fb7ddb2df672e5c2);
#
#
#
#
#
#             var tile_layer_36a487717955a405f191d0dd454ec988 = L.tileLayer(
#                 &quot;http://mt0.google.com/vt/lyrs=y\u0026hl=en\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Satellite&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ece55ddfa0bf4ea0fb7ddb2df672e5c2);
#
#
#             map_ece55ddfa0bf4ea0fb7ddb2df672e5c2.fitBounds(
#                 [[-34.538004006675465, -89.18199854735434], [48.10500007944995, 109.31599868366044]],
#                 {}
#             );
#
#
#         function geo_json_bbb9bd8502abe56656d188db4aa932a4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_bbb9bd8502abe56656d188db4aa932a4_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bbb9bd8502abe56656d188db4aa932a4_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_bbb9bd8502abe56656d188db4aa932a4_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_bbb9bd8502abe56656d188db4aa932a4_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_bbb9bd8502abe56656d188db4aa932a4.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_bbb9bd8502abe56656d188db4aa932a4_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_bbb9bd8502abe56656d188db4aa932a4 = L.geoJson(null, {
#                 onEachFeature: geo_json_bbb9bd8502abe56656d188db4aa932a4_onEachFeature,
#
#                 style: geo_json_bbb9bd8502abe56656d188db4aa932a4_styler,
#                 pointToLayer: geo_json_bbb9bd8502abe56656d188db4aa932a4_pointToLayer
#         });
#
#         function geo_json_bbb9bd8502abe56656d188db4aa932a4_add (data) {
#             geo_json_bbb9bd8502abe56656d188db4aa932a4
#                 .addData(data)
#                 .addTo(map_ece55ddfa0bf4ea0fb7ddb2df672e5c2);
#         }
#             geo_json_bbb9bd8502abe56656d188db4aa932a4_add({&quot;bbox&quot;: [-89.18199854735434, -34.538004006675465, 109.31599868366044, 48.10500007944995], &quot;features&quot;: [{&quot;bbox&quot;: [-57.84000247340134, -34.47999900541754, -57.84000247340134, -34.47999900541754], &quot;geometry&quot;: {&quot;coordinates&quot;: [-57.84000247340134, -34.47999900541754], &quot;type&quot;: &quot;Point&quot;

# %% [markdown]
# **Extracting data which has country capita with its population being greater than 1 million**

# %%
filt=(gdf['pop_max']>1000000) & (gdf['adm0cap'] ==1)

# %%
gdf_filtered = gdf[filt]

# %%
gdf_filtered.shape
# Out:
# (103, 39)

# %%
gdf_filtered.explore(tiles='http://mt0.google.com/vt/lyrs=p&hl=en&x={x}&y={y}&z={z}',
                      attr='Google Terrain', marker_kwds={'radius':10},
                     style_kwds={'fillColor':'red'},popup=['name','pop_max'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18278ee09d31fe0017cf01f7882fc284 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18278ee09d31fe0017cf01f7882fc284&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_18278ee09d31fe0017cf01f7882fc284 = L.map(
#                 &quot;map_18278ee09d31fe0017cf01f7882fc284&quot;,
#                 {
#                     center: [12.660706762488672, 20.30826375512538],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_18278ee09d31fe0017cf01f7882fc284);
#
#
#
#
#
#             var tile_layer_eb25402890a3712401fc9598a0bfbb7c = L.tileLayer(
#                 &quot;http://mt0.google.com/vt/lyrs=p\u0026hl=en\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Terrain&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_18278ee09d31fe0017cf01f7882fc284);
#
#
#             map_18278ee09d31fe0017cf01f7882fc284.fitBounds(
#                 [[-34.856095707590725, -99.1329340602939], [60.17750923256807, 139.74946157054467]],
#                 {}
#             );
#
#
#         function geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d = L.geoJson(null, {
#                 onEachFeature: geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d_onEachFeature,
#
#                 style: geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d_styler,
#                 pointToLayer: geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d_pointToLayer
#         });
#
#         function geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d_add (data) {
#             geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d
#                 .addData(data)
#                 .addTo(map_18278ee09d31fe0017cf01f7882fc284);
#         }
#             geo_json_99cb8de2d7e6579b1aecaaeddf1c3b1d_add({&quot;bbox&quot;: [-99.1329340602939, -34.856095707590725, 139.74946157054467, 60.17750923256807], &quot;features&quot;: [{&quot;bbox&quot;: [51.532967894299304, 25.286556008906587, 51.532967894299304, 25.286556008906587], &quot;geometry&quot;: {&quot;coordinates&quot;: [51.532967894299304, 25.286556008906587], &quot;type&quot;: &quot;Point&quot;},

# %%
gdf_filtered.explore(tiles='http://mt0.google.com/vt/lyrs=s&hl=en&x={x}&y={y}&z={z}',
                      attr='Google Satellite', marker_kwds={'radius':10},
                     style_kwds={'fillColor':'red'},popup=['name','pop_max'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d28cba743ed9d0a016a182908ad49ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d28cba743ed9d0a016a182908ad49ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0d28cba743ed9d0a016a182908ad49ca = L.map(
#                 &quot;map_0d28cba743ed9d0a016a182908ad49ca&quot;,
#                 {
#                     center: [12.660706762488672, 20.30826375512538],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0d28cba743ed9d0a016a182908ad49ca);
#
#
#
#
#
#             var tile_layer_6600e3191f880d15ccd3aa713240a109 = L.tileLayer(
#                 &quot;http://mt0.google.com/vt/lyrs=s\u0026hl=en\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Satellite&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0d28cba743ed9d0a016a182908ad49ca);
#
#
#             map_0d28cba743ed9d0a016a182908ad49ca.fitBounds(
#                 [[-34.856095707590725, -99.1329340602939], [60.17750923256807, 139.74946157054467]],
#                 {}
#             );
#
#
#         function geo_json_8a4322614d68c1b7553e6686087578a2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_8a4322614d68c1b7553e6686087578a2_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8a4322614d68c1b7553e6686087578a2_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_8a4322614d68c1b7553e6686087578a2_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_8a4322614d68c1b7553e6686087578a2_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_8a4322614d68c1b7553e6686087578a2.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_8a4322614d68c1b7553e6686087578a2_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_8a4322614d68c1b7553e6686087578a2 = L.geoJson(null, {
#                 onEachFeature: geo_json_8a4322614d68c1b7553e6686087578a2_onEachFeature,
#
#                 style: geo_json_8a4322614d68c1b7553e6686087578a2_styler,
#                 pointToLayer: geo_json_8a4322614d68c1b7553e6686087578a2_pointToLayer
#         });
#
#         function geo_json_8a4322614d68c1b7553e6686087578a2_add (data) {
#             geo_json_8a4322614d68c1b7553e6686087578a2
#                 .addData(data)
#                 .addTo(map_0d28cba743ed9d0a016a182908ad49ca);
#         }
#             geo_json_8a4322614d68c1b7553e6686087578a2_add({&quot;bbox&quot;: [-99.1329340602939, -34.856095707590725, 139.74946157054467, 60.17750923256807], &quot;features&quot;: [{&quot;bbox&quot;: [51.532967894299304, 25.286556008906587, 51.532967894299304, 25.286556008906587], &quot;geometry&quot;: {&quot;coordinates&quot;: [51.532967894299304, 25.286556008906587], &quot;type&quot;: &quot;Point&quot;}

# %% [markdown]
# **Export data as `GeoJSON`**

# %%
gdf_filtered = gdf_filtered[['name', 'pop_max','geometry']]

gdf_filtered_wrong = gdf_filtered[['name', 'pop_max']]

# %%
type(gdf_filtered), type(gdf_filtered_wrong)
# Out:
# (geopandas.geodataframe.GeoDataFrame, pandas.core.frame.DataFrame)

# %%
gdf_filtered.to_file('populated_capitals.geojson', driver='GeoJSON')

# %%
gpd.read_file('populated_capitals.geojson').explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7514fc2045c47f7bbe7d511d30e75602 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7514fc2045c47f7bbe7d511d30e75602&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7514fc2045c47f7bbe7d511d30e75602 = L.map(
#                 &quot;map_7514fc2045c47f7bbe7d511d30e75602&quot;,
#                 {
#                     center: [12.660706762488672, 20.30826375512538],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7514fc2045c47f7bbe7d511d30e75602);
#
#
#
#
#
#             var tile_layer_0ae5edf37258de23e813d4e5a4e6730e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7514fc2045c47f7bbe7d511d30e75602);
#
#
#             map_7514fc2045c47f7bbe7d511d30e75602.fitBounds(
#                 [[-34.856095707590725, -99.1329340602939], [60.17750923256807, 139.74946157054467]],
#                 {}
#             );
#
#
#         function geo_json_c858497eded2820b08010164a03cb189_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_c858497eded2820b08010164a03cb189_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_c858497eded2820b08010164a03cb189_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_c858497eded2820b08010164a03cb189_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_c858497eded2820b08010164a03cb189_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_c858497eded2820b08010164a03cb189.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c858497eded2820b08010164a03cb189_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c858497eded2820b08010164a03cb189 = L.geoJson(null, {
#                 onEachFeature: geo_json_c858497eded2820b08010164a03cb189_onEachFeature,
#
#                 style: geo_json_c858497eded2820b08010164a03cb189_styler,
#                 pointToLayer: geo_json_c858497eded2820b08010164a03cb189_pointToLayer
#         });
#
#         function geo_json_c858497eded2820b08010164a03cb189_add (data) {
#             geo_json_c858497eded2820b08010164a03cb189
#                 .addData(data)
#                 .addTo(map_7514fc2045c47f7bbe7d511d30e75602);
#         }
#             geo_json_c858497eded2820b08010164a03cb189_add({&quot;bbox&quot;: [-99.1329340602939, -34.856095707590725, 139.74946157054467, 60.17750923256807], &quot;features&quot;: [{&quot;bbox&quot;: [51.532967894299304, 25.286556008906587, 51.532967894299304, 25.286556008906587], &quot;geometry&quot;: {&quot;coordinates&quot;: [51.532967894299304, 25.286556008906587], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Doha&quot;, &quot;pop_max&quot;: 1450000}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-56.17299814703597, -34.856095707590725, -56.17299814703597, -34.856095707590725], &quot;geometry&quot;: {&quot;coordinates&quot;: [-56.17299814703597, -34.856095707590725], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;,

# %%
import fiona

# %%
fiona.supported_drivers
# Out:
# {'ARCGEN': 'r',
#  'DXF': 'rw',
#  'CSV': 'raw',
#  'OpenFileGDB': 'r',
#  'ESRIJSON': 'r',
#  'ESRI Shapefile': 'raw',
#  'FlatGeobuf': 'rw',
#  'GeoJSON': 'raw',
#  'GeoJSONSeq': 'rw',
#  'GPKG': 'raw',
#  'GML': 'rw',
#  'OGR_GMT': 'rw',
#  'GPX': 'rw',
#  'GPSTrackMaker': 'rw',
#  'Idrisi': 'r',
#  'MapInfo File': 'raw',
#  'DGN': 'raw',
#  'PCIDSK': 'raw',
#  'OGR_PDS': 'r',
#  'S57': 'r',
#  'SQLite': 'raw',
#  'TopoJSON': 'r'}
